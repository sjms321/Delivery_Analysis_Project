# %%
import pandas as pd
import numpy as np
missing_values = ["배달전문업체","심부름"]
df = pd.read_csv("seoul_delivery.csv",na_values = missing_values)
df = df.filter(['업종','시군구','통화건수'])
df_grouped=df.groupby(['업종','시군구'])
df_grouped['통화건수'].sum()
for a,b in df_grouped:
    print(a)
    print(b)
# Out:
# ('음식점-족발/보쌈전문', '강남구')
#                  업종  시군구  통화건수
# 0       음식점-족발/보쌈전문  강남구     5
# 1       음식점-족발/보쌈전문  강남구     5
# 108     음식점-족발/보쌈전문  강남구     5
# 113     음식점-족발/보쌈전문  강남구     5
# 265     음식점-족발/보쌈전문  강남구     5
# ...             ...  ...   ...
# 118671  음식점-족발/보쌈전문  강남구     5
# 118677  음식점-족발/보쌈전문  강남구     5
# 118970  음식점-족발/보쌈전문  강남구     5
# 118985  음식점-족발/보쌈전문  강남구     5
# 118996  음식점-족발/보쌈전문  강남구     5
#
# [1399 rows x 3 columns]
# ('음식점-족발/보쌈전문', '강동구')
#                  업종  시군구  통화건수
# 567     음식점-족발/보쌈전문  강동구     5
# 803     음식점-족발/보쌈전문  강동구     5
# 1074    음식점-족발/보쌈전문  강동구     5
# 1338    음식점-족발/보쌈전문  강동구     5
# 1586    음식점-족발/보쌈전문  강동구     5
# ...             ...  ...   ...
# 118373  음식점-족발/보쌈전문  강동구    15
# 118686  음식점-족발/보쌈전문  강동구    16
# 118962  음식점-족발/보쌈전문  강동구     5
# 118963  음식점-족발/보쌈전문  강동구     5
# 118992  음식점-족발/보쌈전문  강동구     5
#
# [677 rows x 3 columns]
# ('음식점-족발/보쌈전문', '강북구')
#                  업종  시군구  통화건수
# 444     음식점-족발/보쌈전문  강북구     5
# ...

# %%
pd.set_option('display.max_rows', 10000000)
df_grouped['통화건수'].sum()
# Out:
# 업종           시군구
# 음식점-족발/보쌈전문  강남구      7318
#              강동구      4173
#              강북구      4970
#              강서구      6978
#              관악구      1156
#              광진구      1331
#              구로구      2428
#              금천구      1697
#              노원구      3788
#              도봉구       890
#              동대문구     4185
#              동작구      4606
#              마포구      2531
#              서대문구     5234
#              서초구      5477
#              성동구      4031
#              성북구      4654
#              송파구      4565
#              양천구      1010
#              영등포구     5591
#              용산구      3012
#              은평구      2303
#              종로구      1670
#              중구       4994
#              중랑구      3599
# 음식점-중국음식     강남구     42935
#              강동구     19266
#              강북구     19239
#              강서구     35340
#              관악구      4409
#              광진구      5005
#              구로구      9442
#              금천구      6053
# ...

# %%
GDP_seoul = pd.read_csv('report.txt',sep='\t')
GDP_seoul=GDP_seoul.filter(['자치구','인구수','월소득'])

GDP_seoul
# Out:
#      자치구     인구수  월소득
# 0    종로구  161984  435
# 1     중구  136469  345
# 2    용산구  246165  385
# 3    성동구  307193  395
# 4    광진구  365990  350
# 5   동대문구  362793  370
# 6    중랑구  400678  400
# 7    성북구  454532  390
# 8    강북구  316750  380
# 9    도봉구  333495  450
# 10   노원구  535495  405
# 11   은평구  482509  430
# 12  서대문구  325875  450
# 13   마포구  386086  425
# 14   양천구  460532  370
# 15   강서구  595703  460
# 16   구로구  438308  425
# 17   금천구  251370  390
# 18  영등포구  404766  430
# 19   동작구  407802  435
# 20   관악구  516662  385
# 21   서초구  434801  510
# 22   강남구  549898  500
# 23   송파구  680883  475
# 24   강동구  457042  490

# %%
GDP_seoul['자치구'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
df['시군구'].unique()
# Out:
# array(['강남구', '강서구', '동작구', '노원구', '서대문구', '서초구', '성동구', '송파구', '구로구',
#        '영등포구', '중구', '관악구', '동대문구', '강북구', '은평구', '종로구', '중랑구', '강동구',
#        '금천구', '마포구', '광진구', '성북구', '용산구', '양천구', '도봉구'], dtype=object)

# %%
China=df.query('업종.str.contains("중국")')

# %%
bb = China.groupby('시군구')
bb =bb['통화건수'].sum()
bb
# Out:
# 시군구
# 강남구     42935
# 강동구     19266
# 강북구     19239
# 강서구     35340
# 관악구      4409
# 광진구      5005
# 구로구      9442
# 금천구      6053
# 노원구     15121
# 도봉구      2831
# 동대문구    21560
# 동작구     25413
# 마포구     14548
# 서대문구    25241
# 서초구     26391
# 성동구     20509
# 성북구     15359
# 송파구     21209
# 양천구      5397
# 영등포구    17222
# 용산구     20577
# 은평구     11742
# 종로구     10974
# 중구      29069
# 중랑구     13601
# Name: 통화건수, dtype: int64

# %%
bb.index
# Out:
# Index(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구',
#        '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구',
#        '용산구', '은평구', '종로구', '중구', '중랑구'],
#       dtype='object', name='시군구')

# %%
temp2 = GDP_seoul.groupby('자치구')
temp2 = temp2['인구수'].sum()
temp2
# Out:
# 자치구
# 강남구     549898
# 강동구     457042
# 강북구     316750
# 강서구     595703
# 관악구     516662
# 광진구     365990
# 구로구     438308
# 금천구     251370
# 노원구     535495
# 도봉구     333495
# 동대문구    362793
# 동작구     407802
# 마포구     386086
# 서대문구    325875
# 서초구     434801
# 성동구     307193
# 성북구     454532
# 송파구     680883
# 양천구     460532
# 영등포구    404766
# 용산구     246165
# 은평구     482509
# 종로구     161984
# 중구      136469
# 중랑구     400678
# Name: 인구수, dtype: int64

# %%
temptable = pd.concat([bb, temp2], axis=1)

temptable['1인당 배달비율']=temptable['통화건수'].astype('float')/temptable['인구수'].astype('float')

# %%
temptable
# Out:
#        통화건수     인구수  1인당 배달비율
# 강남구   42935  549898  0.078078
# 강동구   19266  457042  0.042154
# 강북구   19239  316750  0.060739
# 강서구   35340  595703  0.059325
# 관악구    4409  516662  0.008534
# 광진구    5005  365990  0.013675
# 구로구    9442  438308  0.021542
# 금천구    6053  251370  0.024080
# 노원구   15121  535495  0.028237
# 도봉구    2831  333495  0.008489
# 동대문구  21560  362793  0.059428
# 동작구   25413  407802  0.062317
# 마포구   14548  386086  0.037681
# 서대문구  25241  325875  0.077456
# 서초구   26391  434801  0.060697
# 성동구   20509  307193  0.066763
# 성북구   15359  454532  0.033791
# 송파구   21209  680883  0.031149
# 양천구    5397  460532  0.011719
# 영등포구  17222  404766  0.042548
# 용산구   20577  246165  0.083590
# 은평구   11742  482509  0.024335
# 종로구   10974  161984  0.067747
# 중구    29069  136469  0.213008
# 중랑구   13601  400678  0.033945

# %%
temp3 = GDP_seoul.groupby('자치구')
temp3 = temp3['월소득'].sum()
temp3
# Out:
# 자치구
# 강남구     500
# 강동구     490
# 강북구     380
# 강서구     460
# 관악구     385
# 광진구     350
# 구로구     425
# 금천구     390
# 노원구     405
# 도봉구     450
# 동대문구    370
# 동작구     435
# 마포구     425
# 서대문구    450
# 서초구     510
# 성동구     395
# 성북구     390
# 송파구     475
# 양천구     370
# 영등포구    430
# 용산구     385
# 은평구     430
# 종로구     435
# 중구      345
# 중랑구     400
# Name: 월소득, dtype: int64

# %%
temptable = pd.concat([temptable, temp3], axis=1)

# %%
temptable
# Out:
#        통화건수     인구수  1인당 배달비율  월소득
# 자치구
# 강남구   42935  549898  0.078078  500
# 강동구   19266  457042  0.042154  490
# 강북구   19239  316750  0.060739  380
# 강서구   35340  595703  0.059325  460
# 관악구    4409  516662  0.008534  385
# 광진구    5005  365990  0.013675  350
# 구로구    9442  438308  0.021542  425
# 금천구    6053  251370  0.024080  390
# 노원구   15121  535495  0.028237  405
# 도봉구    2831  333495  0.008489  450
# 동대문구  21560  362793  0.059428  370
# 동작구   25413  407802  0.062317  435
# 마포구   14548  386086  0.037681  425
# 서대문구  25241  325875  0.077456  450
# 서초구   26391  434801  0.060697  510
# 성동구   20509  307193  0.066763  395
# 성북구   15359  454532  0.033791  390
# 송파구   21209  680883  0.031149  475
# 양천구    5397  460532  0.011719  370
# 영등포구  17222  404766  0.042548  430
# 용산구   20577  246165  0.083590  385
# 은평구   11742  482509  0.024335  430
# 종로구   10974  161984  0.067747  435
# 중구    29069  136469  0.213008  345
# 중랑구   13601  400678  0.033945  400

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
temptable=temptable.sort_values(by=['월소득'], axis=0)
temptable
# Out:
#        통화건수     인구수  1인당 배달비율  월소득
# 자치구
# 중구    29069  136469  0.213008  345
# 광진구    5005  365990  0.013675  350
# 양천구    5397  460532  0.011719  370
# 동대문구  21560  362793  0.059428  370
# 강북구   19239  316750  0.060739  380
# 용산구   20577  246165  0.083590  385
# 관악구    4409  516662  0.008534  385
# 성북구   15359  454532  0.033791  390
# 금천구    6053  251370  0.024080  390
# 성동구   20509  307193  0.066763  395
# 중랑구   13601  400678  0.033945  400
# 노원구   15121  535495  0.028237  405
# 마포구   14548  386086  0.037681  425
# 구로구    9442  438308  0.021542  425
# 영등포구  17222  404766  0.042548  430
# 은평구   11742  482509  0.024335  430
# 종로구   10974  161984  0.067747  435
# 동작구   25413  407802  0.062317  435
# 서대문구  25241  325875  0.077456  450
# 도봉구    2831  333495  0.008489  450
# 강서구   35340  595703  0.059325  460
# 송파구   21209  680883  0.031149  475
# 강동구   19266  457042  0.042154  490
# 강남구   42935  549898  0.078078  500
# 서초구   26391  434801  0.060697  510

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
plt.figure(figsize=(20,10))

# %%
ja=df.query('업종.str.contains("중국")')
cc = ja.groupby('시군구')
cc =cc['통화건수'].sum()
t2 = GDP_seoul.groupby('자치구')
t2 = t2['인구수'].sum()
t2table = pd.concat([cc, t2], axis=1)
t2table['1인당 배달비율']=t2table['통화건수'].astype('float')/t2table['인구수'].astype('float')
t3 = GDP_seoul.groupby('자치구')
t3 = t3['월소득'].sum()
t2table = pd.concat([t2table, t3], axis=1)
t2table=t2table.sort_values(by=['월소득'], axis=0)
plt.figure(figsize=(20,10))
jja=t2table['통화건수']

# %%
bo=df.query('업종.str.contains("보쌈")')
cc = bo.groupby('시군구')
cc =cc['통화건수'].sum()
t2 = GDP_seoul.groupby('자치구')
t2 = t2['인구수'].sum()
t2table = pd.concat([cc, t2], axis=1)
t2table['1인당 배달비율']=t2table['통화건수'].astype('float')/t2table['인구수'].astype('float')
t3 = GDP_seoul.groupby('자치구')
t3 = t3['월소득'].sum()
t2table = pd.concat([t2table, t3], axis=1)
t2table=t2table.sort_values(by=['월소득'], axis=0)
plt.figure(figsize=(20,10))
ssam=t2table['통화건수']

# %%
ck=df.query('업종.str.contains("치킨")')
cc = ck.groupby('시군구')
cc =cc['통화건수'].sum()
t2 = GDP_seoul.groupby('자치구')
t2 = t2['인구수'].sum()
t2table = pd.concat([cc, t2], axis=1)
t2table['1인당 배달비율']=t2table['통화건수'].astype('float')/t2table['인구수'].astype('float')
t3 = GDP_seoul.groupby('자치구')
t3 = t3['월소득'].sum()
t2table = pd.concat([t2table, t3], axis=1)
t2table=t2table.sort_values(by=['월소득'], axis=0)
plt.figure(figsize=(20,10))
ckck=t2table['통화건수']

# %%
ck=df.query('업종.str.contains("피자")')
cc = ck.groupby('시군구')
cc =cc['통화건수'].sum()
t2 = GDP_seoul.groupby('자치구')
t2 = t2['인구수'].sum()
t2table = pd.concat([cc, t2], axis=1)
t2table['1인당 배달비율']=t2table['통화건수'].astype('float')/t2table['인구수'].astype('float')
t3 = GDP_seoul.groupby('자치구')
t3 = t3['월소득'].sum()
t2table = pd.concat([t2table, t3], axis=1)
t2table=t2table.sort_values(by=['월소득'], axis=0)
plt.figure(figsize=(20,10))
pipi=t2table['통화건수']

# %%
plt.figure(figsize=(20,10))
plt.plot(temptable.index,jja,temptable.index,ssam,temptable.index,ckck,temptable.index,pipi)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
A=jja

A=A.to_frame()
#ssam=ssam.to_frame()
#pipi=pipi.to_frame()
#ckck=ckck.to_frame()

#pipi

# %%
totaltable=pd.concat([A,ssam,pipi,ckck],axis=1)
totaltable
# Out:
#        통화건수  통화건수   통화건수   통화건수
# 자치구
# 중구    29069  4994   6580  19309
# 광진구    5005  1331   2857   5591
# 양천구    5397  1010   2787   6652
# 동대문구  21560  4185   6615  12571
# 강북구   19239  4970  10407  24674
# 용산구   20577  3012   6732  15719
# 관악구    4409  1156   3338   5810
# 성북구   15359  4654   6566  18867
# 금천구    6053  1697   3702   8250
# 성동구   20509  4031   7099  21038
# 중랑구   13601  3599   6543  14994
# 노원구   15121  3788   8449  24257
# 마포구   14548  2531   6802  16325
# 구로구    9442  2428   4965  14895
# 영등포구  17222  5591   9408  28983
# 은평구   11742  2303   6454  17926
# 종로구   10974  1670   2620   7746
# 동작구   25413  4606  12280  34192
# 서대문구  25241  5234   8813  23952
# 도봉구    2831   890   2044   3732
# 강서구   35340  6978  14474  46134
# 송파구   21209  4565   7295  26928
# 강동구   19266  4173   8959  18553
# 강남구   42935  7318  12064  32281
# 서초구   26391  5477   8514  25546

# %%
totaltable.columns=["짜장","보쌈","피자","치킨"]
totaltable
totaltable['자치구']=totaltable.index
totaltable
# Out:
#          짜장    보쌈     피자     치킨   자치구
# 자치구
# 중구    29069  4994   6580  19309    중구
# 광진구    5005  1331   2857   5591   광진구
# 양천구    5397  1010   2787   6652   양천구
# 동대문구  21560  4185   6615  12571  동대문구
# 강북구   19239  4970  10407  24674   강북구
# 용산구   20577  3012   6732  15719   용산구
# 관악구    4409  1156   3338   5810   관악구
# 성북구   15359  4654   6566  18867   성북구
# 금천구    6053  1697   3702   8250   금천구
# 성동구   20509  4031   7099  21038   성동구
# 중랑구   13601  3599   6543  14994   중랑구
# 노원구   15121  3788   8449  24257   노원구
# 마포구   14548  2531   6802  16325   마포구
# 구로구    9442  2428   4965  14895   구로구
# 영등포구  17222  5591   9408  28983  영등포구
# 은평구   11742  2303   6454  17926   은평구
# 종로구   10974  1670   2620   7746   종로구
# 동작구   25413  4606  12280  34192   동작구
# 서대문구  25241  5234   8813  23952  서대문구
# 도봉구    2831   890   2044   3732   도봉구
# 강서구   35340  6978  14474  46134   강서구
# 송파구   21209  4565   7295  26928   송파구
# 강동구   19266  4173   8959  18553   강동구
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(totaltable.index,totaltable['짜장'],label='짜장')
plt.plot(totaltable.index,totaltable['보쌈'],label='보쌈')
plt.plot(totaltable.index,totaltable['치킨'],label='치킨')
plt.plot(totaltable.index,totaltable['피자'],label='피자')
plt.xlabel('서울 자치구(월평균 소득)',fontsize='x-large')
plt.ylabel('배달량',fontsize='x-large')
plt.legend(fontsize='x-large')
plt.show()

# %%
import seaborn as sns

# %%
temptable
totaltable['총배달량']=temptable['통화건수']
totaltable['월소득']=temptable['월소득']
totaltable['인구수']=temptable['인구수']

totaltable_filter=totaltable.filter(['총배달량','월소득','인구수'])
sns.pairplot(totaltable_filter)
plt.show()

# %%
sns.lmplot(x="월소득", y="총배달량", data=totaltable_filter)

# %%
totaltable
# Out:
#          짜장    보쌈     피자     치킨   자치구   총배달량  월소득     인구수
# 자치구
# 중구    29069  4994   6580  19309    중구  29069  345  136469
# 광진구    5005  1331   2857   5591   광진구   5005  350  365990
# 양천구    5397  1010   2787   6652   양천구   5397  370  460532
# 동대문구  21560  4185   6615  12571  동대문구  21560  370  362793
# 강북구   19239  4970  10407  24674   강북구  19239  380  316750
# 용산구   20577  3012   6732  15719   용산구  20577  385  246165
# 관악구    4409  1156   3338   5810   관악구   4409  385  516662
# 성북구   15359  4654   6566  18867   성북구  15359  390  454532
# 금천구    6053  1697   3702   8250   금천구   6053  390  251370
# 성동구   20509  4031   7099  21038   성동구  20509  395  307193
# 중랑구   13601  3599   6543  14994   중랑구  13601  400  400678
# 노원구   15121  3788   8449  24257   노원구  15121  405  535495
# 마포구   14548  2531   6802  16325   마포구  14548  425  386086
# 구로구    9442  2428   4965  14895   구로구   9442  425  438308
# 영등포구  17222  5591   9408  28983  영등포구  17222  430  404766
# ...

# %%
sns.heatmap(data = totaltable.corr(),annot=True,fmt='.2f',cmap='Greens')
# Out:
# <AxesSubplot:>

# %%
popultable=totaltable.sort_values(by=['인구수'],axis=0)

# %%
sns.lmplot(x="인구수", y="치킨", data=popultable)

# %%
sns.lmplot(x="인구수", y="짜장", data=popultable)

# %%
totaltable
ntotaltable1=totaltable[['짜장','월소득']]
ntotaltable1.columns=['통화건수','월소득']
ntotaltable1['음식종류']='짜장'



ntotaltable2=totaltable[['보쌈','월소득']]
ntotaltable2.columns=['통화건수','월소득']
ntotaltable2['음식종류']='보쌈'

ntotaltable3=totaltable[['피자','월소득']]
ntotaltable3.columns=['통화건수','월소득']
ntotaltable3['음식종류']='피자'


ntotaltable4=totaltable[['치킨','월소득']]
ntotaltable4.columns=['통화건수','월소득']
ntotaltable4['음식종류']='치킨'

linetable=pd.concat([ntotaltable1,ntotaltable2,ntotaltable3,ntotaltable4],axis=0)
linetable
# Out:
# C:\Users\user\anaconda3\envs\myR\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\user\anaconda3\envs\myR\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\user\anaconda3\envs\myR\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# ...

# %%
qualitative_colors = sns.color_palette("Set3", 10)
plt.figure(figsize=(20,10))
ax = sns.lineplot(x = '자치구', y = '통화건수',hue="음식종류",data = linetable,err_style='bars')
plt.legend(fontsize=12, loc='best')
plt.show()

# %%
# %matplotlib notebook
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(totaltable['월소득'], totaltable['치킨'], totaltable['인구수'],'.',)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
